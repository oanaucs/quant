# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
from scipy.interpolate import make_interp_spline, BSpline, make_lsq_spline
from scipy.optimize import curve_fit

# %%
pruning_filename = './../eval_results/alexnet/eval_alexnet_pruning.csv'
pruning_quant_filename = './../eval_results/alexnet/eval_alexnet_pruning_quant.csv'

# %%
pruning_data = pd.read_csv(pruning_filename, decimal=',')
pruning_quant_data = pd.read_csv(pruning_quant_filename, decimal=',')

# %%
print(pruning_data)
# Out:
#    sparsity_level  accuracy  params_set_to_0  size_mb_after_huffman  \
# 0             0.0     0.662         56885962                  208.8
# 1             0.1     0.699         51320174                  195.8
# 2             0.2     0.704         45643001                  180.1
# 3             0.3     0.705         40077743                  162.7
# 4             0.4     0.705         34511007                  144.5
# 5             0.5     0.704         28947079                  126.5
# 6             0.6     0.706         23494555                  107.9
# 7             0.7     0.704         17906138                   87.9
# 8             0.8     0.701         12336115                   67.2
#
#    avg_inference_time  compression_ratio  Unnamed: 6         flops  \
# 0                0.14         100.000000         NaN  1.102796e+10
# 1                0.15          93.773946         NaN           NaN
# 2                0.14          86.254789         NaN           NaN
# 3                0.14          77.921456         NaN           NaN
# 4                0.15          69.204981         NaN           NaN
# 5                0.15          60.584291         NaN           NaN
# 6                0.14          51.676245         NaN           NaN
# 7                0.13          42.097701         NaN           NaN
# 8                0.14          32.183908         NaN           NaN
#
#    num_parameters
# 0      56885962.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN

# %%
pruning_data['accuracy_loss'] = pruning_data['accuracy']
pruning_data['accuracy_loss'] -= pruning_data['accuracy'][0]

# %%
print(pruning_quant_data)
# Out:
#    bits  accuracy  size_mb_after_huffman  compression_ratio  avg_quant_time  \
# 0     4     0.701                   34.4          16.475096           11.96
# 1     5     0.703                   40.0          19.157088           22.35
# 2     6     0.706                   45.0          21.551724           43.31
# 3     7     0.705                   49.9          23.898467           85.03
# 4     8     0.706                   53.3          25.526820          170.34
#
#    layer_quant_time
# 0             84.18
# 1            110.47
# 2            132.41
# 3            115.97
# 4            199.80

# %%
pruning_quant_data['accuracy_loss'] = pruning_quant_data['accuracy']
pruning_quant_data['accuracy_loss'] = pruning_data['accuracy'][0] - pruning_quant_data['accuracy']

# %%
print(pruning_data['accuracy_loss'].to_numpy())
# Out:
# [0.    0.037 0.042 0.043 0.043 0.042 0.044 0.042 0.039]

# %%
# accuracy_loss = pruning_data['accuracy_loss'].to_numpy()
# compression_line =  pruning_data['Compression %'].to_numpy()

# xnew = np.linspace(0, 10, 300) #300 represents number of points to make between T.min and T.max

# spl = make_interp_spline(compression_line, accuracy_loss, k=2) #BSpline object
# power_smooth = spl(xnew)

# # plt.ylim((-1, 0.5))
# plt.plot(xnew,power_smooth)
# plt.plot(compression_line, accuracy_loss, 'bo')
# plt.show()

# %%
# def func(x, a, b, c):
#     return a * np.exp(b * x) + c
# popt, pcov = curve_fit(func, accuracy_loss, compression_line)

# vals = []
# c = np.linspace(0, 0.5, 100)
# for v in c:
#     vals.append(func(v, *popt))
    
#     plt.xlim((-0.1, 0.1))
# plt.ylim((0, 1.2))
# # plt.plot(c, vals)
# # plt.plot(accuracy_loss, compression_line, 'bo')

# %%
# plot points
fig, ax = plt.subplots()

ax.grid()
plt.plot(pruning_data['compression_ratio'], pruning_data['accuracy_loss'], 'bo', color='green', label='pruning')
plt.plot(pruning_quant_data['compression_ratio'], pruning_quant_data['accuracy_loss'], 'bo', color='red', label='pruning+quantization')
plt.ylim((-0.1, 0.05))
plt.xlabel('model ratio')
plt.ylabel('accuracy loss')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# %%
# plot time step points
fig, ax = plt.subplots()

ax.grid()
poly = np.polyfit(pruning_quant_data['avg_quant_time'], pruning_quant_data['bits'], 2)
x = np.linspace(pruning_quant_data['avg_quant_time'].min(), pruning_quant_data['avg_quant_time'].max(), 100)
p = np.poly1d(poly)
plt.plot(x, p(x))
plt.plot(pruning_quant_data['avg_quant_time'], pruning_quant_data['bits'], 'bo', color='darkblue', label='average step time')

poly2 = np.polyfit(pruning_quant_data['layer_quant_time'], pruning_quant_data['bits'], 2)
x2 = np.linspace(pruning_quant_data['layer_quant_time'].min(), pruning_quant_data['layer_quant_time'].max(), 100)
p2 = np.poly1d(poly2)
plt.plot(x2, p2(x2))
plt.plot(pruning_quant_data['layer_quant_time'], pruning_quant_data['bits'], 'bo', color='orange', label='layer quantization time')
plt.xlabel('time[s]')
plt.ylabel('bits')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-7f6de3919607> in <module>
#       6 x = np.linspace(pruning_quant_data['avg_quant_time'].min(), pruning_quant_data['avg_quant_time'].max(), 100)
#       7 p = np.exp(poly)
# ----> 8 plt.plot(x, p(x))
#       9 plt.plot(pruning_quant_data['avg_quant_time'], pruning_quant_data['bits'], 'bo', color='darkblue', label='average step time')
#      10
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
# plot points
fig, ax = plt.subplots()

ax.grid()
poly = np.polyfit(pruning_data['sparsity_level'], pruning_data['compression_ratio'], 10)
x = np.linspace(pruning_data['sparsity_level'].min(), pruning_data['sparsity_level'].max(), 100)
p = np.poly1d(poly)
plt.plot(x, p(x))
plt.plot(pruning_data['sparsity_level'], pruning_data['compression_ratio'], 'bo', color='darkblue')
plt.xlabel('sparsity level')
plt.ylabel('compression ratio')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# /home/oanaucs/virtualenvs/py_3.6_tf_1.5/lib/python3.6/site-packages/ipykernel_launcher.py:5: RankWarning: Polyfit may be poorly conditioned
#   """
# No handles with labels found to put in legend.

# %%
# plot points
fig, ax = plt.subplots()

ax.grid()
poly = np.polyfit(pruning_data['sparsity_level'], pruning_data['accuracy_loss'], 6)
x = np.linspace(pruning_data['sparsity_level'].min(), pruning_data['sparsity_level'].max(), 100)
p = np.poly1d(poly)
plt.plot(x, p(x))
plt.plot(pruning_data['sparsity_level'], pruning_data['accuracy_loss'], 'bo', color='darkblue')
plt.xlabel('sparsity level')
plt.ylabel('accuracy loss')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# No handles with labels found to put in legend.

# %%
threshold_filename = './../eval_results/alexnet/eval_alexnet_pruning_threshold.csv'
threshold_data = pd.read_csv(threshold_filename, decimal=',')

# %%
threshold_data['accuracy_loss'] = threshold_data['accuracy']
threshold_data['accuracy_loss'] -= pruning_data['accuracy'][0]
print(threshold_data)
# Out:
#    threshold  accuracy  params_set_to_0  size_mb_after_huffman  \
# 0      0.010     0.693         32630686                  138.4
# 1      0.020     0.684          8417456                   53.3
# 2      0.024     0.609          3624168                   30.2
# 3      0.300     0.102          1176849                   19.5
#
#    compression_ratio  step_time  accuracy_loss
# 0           1.508671      0.140          0.031
# 1           3.917448      0.135          0.022
# 2           6.913907      0.150         -0.053
# 3          10.707692      0.150         -0.560

# %%
threshold_data.at[3, 'threshold'] = 0.03
print(threshold_data)
# Out:
#    threshold  accuracy  params_set_to_0  size_mb_after_huffman  \
# 0      0.010     0.693         32630686                  138.4
# 1      0.020     0.684          8417456                   53.3
# 2      0.024     0.609          3624168                   30.2
# 3      0.030     0.102          1176849                   19.5
#
#    compression_ratio  step_time  accuracy_loss
# 0           1.508671      0.140          0.031
# 1           3.917448      0.135          0.022
# 2           6.913907      0.150         -0.053
# 3          10.707692      0.150         -0.560

# %%
# plot points
fig, ax = plt.subplots()

ax.grid()
poly = np.polyfit(threshold_data['threshold'], threshold_data['accuracy_loss'], 2)
x = np.linspace(threshold_data['threshold'].min(), threshold_data['threshold'].max(), 100)
p = np.poly1d(poly)
plt.plot(x, p(x))
plt.plot(threshold_data['threshold'], threshold_data['accuracy_loss'], 'bo', color='darkblue')
plt.xlabel('threshold value')
plt.ylabel('accuracy loss')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# No handles with labels found to put in legend.

# %%
# plot points
fig, ax = plt.subplots()

ax.grid()
poly = np.polyfit(pruning_data['size_mb_after_huffman'], pruning_data['sparsity_level'], 1)
x = np.linspace(pruning_data['size_mb_after_huffman'].min(), pruning_data['size_mb_after_huffman'].max(), 100)
p = np.poly1d(poly)
plt.plot(x, p(x))
plt.plot(pruning_data['size_mb_after_huffman'], pruning_data['sparsity_level'], 'bo', color='darkblue')
plt.ylabel('sparsity level')
plt.xlabel('model size[MB]')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# No handles with labels found to put in legend.

# %%
# plot points
fig, ax = plt.subplots()
ax.grid()
poly = np.polyfit(threshold_data['size_mb_after_huffman'], threshold_data['threshold'], 2)
x = np.linspace(threshold_data['size_mb_after_huffman'].min(), threshold_data['size_mb_after_huffman'].max(), 100)
p = np.poly1d(poly)
plt.plot(x, p(x))
plt.plot(threshold_data['size_mb_after_huffman'], threshold_data['threshold'], 'bo', color='red')
plt.ylabel('threshold value')
plt.xlabel('model size[MB]')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# No handles with labels found to put in legend.

# %%
# plot points
fig, ax = plt.subplots()
ax.grid()
poly = np.polyfit(threshold_data['threshold'], threshold_data['accuracy'], 5)
x = np.linspace(threshold_data['threshold'].min(), threshold_data['threshold'].max(), 100)
p = np.poly1d(poly)
plt.plot(x, p(x))
plt.plot(threshold_data['threshold'], threshold_data['accuracy'], 'bo', color='green')
plt.ylabel('accuracy')
plt.xlabel('threshold value')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# /home/oanaucs/virtualenvs/py_3.6_tf_1.5/lib/python3.6/site-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# Text(0.5, 0, 'threshold value')

# %%
# plot points
fig, ax = plt.subplots()
ax.grid()
poly = np.polyfit(pruning_data['sparsity_level'], pruning_data['accuracy'], 6)
x = np.linspace(pruning_data['sparsity_level'].min(), pruning_data['sparsity_level'].max(), 100)
p = np.poly1d(poly)
plt.plot(x, p(x))
plt.plot(pruning_data['sparsity_level'], pruning_data['accuracy'], 'bo', color='darkblue')
plt.ylabel('accuracy')
plt.xlabel('sparsity level')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# Text(0.5, 0, 'sparsity level')

# %%
# plot points
fig, ax = plt.subplots()
ax.grid()
plt.plot(pruning_quant_data['bits'], pruning_quant_data['accuracy'], 'bo', color='darkblue')
plt.ylabel('accuracy')
plt.xlabel('bits')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# Text(0.5, 0, 'bits')

# %%
# plot points
fig, ax = plt.subplots()
ax.grid()
poly = np.polyfit(pruning_quant_data['size_mb_after_huffman'], pruning_quant_data['bits'], 6)
x = np.linspace(pruning_quant_data['size_mb_after_huffman'].min(), pruning_quant_data['size_mb_after_huffman'].max(), 100)
p = np.poly1d(poly)
plt.plot(x, p(x))
plt.plot(pruning_quant_data['size_mb_after_huffman'], pruning_quant_data['bits'], 'bo', color='darkblue')
plt.xlabel('model size[MB]')
plt.ylabel('bits')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# /home/oanaucs/virtualenvs/py_3.6_tf_1.5/lib/python3.6/site-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# Text(0, 0.5, 'bits')
